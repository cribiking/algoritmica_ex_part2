# %% [markdown]
# ## Exercice 4
#
# - **Apartat 1:** Assume m = ∞. Design a greedy algorithm that accomplishes our objective. Try to use the minimum number of colors (no need to ensure
# optimality here).
#     - Our objective is to colour the graph such that two adjacent nodes do not share the same color.

# %%
#Given a graph of 'n' vertices, a node 'N' and a set of 'm' colors
#Gready aproach: 

def main():
    # Example usage
    from graph_tools import Graph

    # Create a directed graph with four nodes and two edges
    
    """
    networkx
    def colorGraphs(colors : int , n : int , N : node):

        colors = 0 #Colors
        n = 0 #num of nodes
        g = Graph(directed=True)
        g.add_edge(1, 2)
        g.add_edge(2, 3)
        g.add_edge(3, 4)
        g.add_edge(1, 4)
        print(g)
    

        # Find all shortest paths from vertex 1
        dist, prev = g.dijkstra(4)
        print(dist)

    def getAdjacent(N : node):
    """

if __name__ == "__main__":
    main()
# Out:
# // Generated by graph-tools (version 1.1) at 2025/33/05/07/25 16:33:24]
# // directed, 4 vertices, 4 edges
# digraph export_dot {
# graph [start="1"]
#   node [color=gray90,style=filled];
#   1;
#   2;
#   3;
#   4;
#   1 -> 2;
#   1 -> 4;
#   2 -> 3;
#   3 -> 4;
# }
#
# {1: inf, 2: inf, 3: inf, 4: 0}
